# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# Execute_Unit_Tests.ipynb
import unittest
import sys
import os

# 1. Add the project directory to sys.path so we can import our modules
# Adjust the path based on your folder structure in Workspace
sys.path.append(os.path.abspath('..')) 

from tests.test_suite import ZillowDLTTests

# 2. Run the suite
suite = unittest.TestLoader().loadTestsFromTestCase(ZillowDLTTests)
runner = unittest.TextTestRunner(verbosity=2)
result = runner.run(suite)

# 3. Output results clearly
if result.wasSuccessful():
    print("\nSUCCESS: All business rules and standardization tests passed.")
else:
    print("\nFAILURE: One or more tests failed. Review the logs above.")
    # Optional: Exit with error if running in a CI/CD job
    # sys.exit(1)
